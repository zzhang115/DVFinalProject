# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import statsmodels.api as sm 
import patsy
# Out:
# C:\Users\Alex_Guo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = pd.read_csv('FAO.csv', encoding = "ISO-8859-1")

# %%
data.head(10)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
# 5               AFG          2  Afghanistan       2514
# 6               AFG          2  Afghanistan       2517
# 7               AFG          2  Afghanistan       2520
# 8               AFG          2  Afghanistan       2531
# 9               AFG          2  Afghanistan       2536
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# ...

# %%
len(data)
# Out:
# 21477

# %%
# filter out the Ukraine's data
data = data[data.Area == "Ukraine"]

# %%
data.head(5)
# Out:
#       Area Abbreviation  Area Code     Area  Item Code  \
# 19867               UKR        230  Ukraine       2511
# 19868               UKR        230  Ukraine       2511
# 19869               UKR        230  Ukraine       2805
# 19870               UKR        230  Ukraine       2513
# 19871               UKR        230  Ukraine       2513
#
#                            Item  Element Code Element         Unit  latitude  \
# 19867        Wheat and products          5521    Feed  1000 tonnes     48.38
# 19868        Wheat and products          5142    Food  1000 tonnes     48.38
# 19869  Rice (Milled Equivalent)          5142    Food  1000 tonnes     48.38
# 19870       Barley and products          5521    Feed  1000 tonnes     48.38
# 19871       Barley and products          5142    Food  1000 tonnes     48.38
#
#        longitude  ...     Y2004   Y2005   Y2006   Y2007   Y2008   Y2009  \
# 19867      31.17  ...    5000.0  5536.0  4050.0  4050.0  7250.0  3000.0
# ...

# %%
len(data)
# Out:
# 134

# %%
df = pd.DataFrame(columns=['Year', 'Qty'])
df
# Out:
# Empty DataFrame
# Columns: [Year, Qty]
# Index: []

# %%
'''
df.loc[0] =  [1961, data[data.Element == "Food"].Y1961.sum()]
df.loc[1] =  [1962, data[data.Element == "Food"].Y1962.sum()]
df.loc[2] =  [1963, data[data.Element == "Food"].Y1963.sum()]
df.loc[3] =  [1964, data[data.Element == "Food"].Y1964.sum()]
df.loc[4] =  [1965, data[data.Element == "Food"].Y1965.sum()]
df.loc[5] =  [1966, data[data.Element == "Food"].Y1966.sum()]
df.loc[6] =  [1967, data[data.Element == "Food"].Y1967.sum()]
df.loc[7] =  [1968, data[data.Element == "Food"].Y1968.sum()]
df.loc[8] =  [1969, data[data.Element == "Food"].Y1969.sum()]
df.loc[9] =  [1970, data[data.Element == "Food"].Y1970.sum()]
df.loc[10] =  [1971, data[data.Element == "Food"].Y1971.sum()]
df.loc[11] =  [1972, data[data.Element == "Food"].Y1972.sum()]
df.loc[12] =  [1973, data[data.Element == "Food"].Y1973.sum()]
df.loc[13] =  [1974, data[data.Element == "Food"].Y1974.sum()]
df.loc[14] =  [1975, data[data.Element == "Food"].Y1975.sum()]
df.loc[15] =  [1976, data[data.Element == "Food"].Y1976.sum()]
df.loc[16] =  [1977, data[data.Element == "Food"].Y1977.sum()]
df.loc[17] =  [1978, data[data.Element == "Food"].Y1978.sum()]
df.loc[18] =  [1979, data[data.Element == "Food"].Y1979.sum()]
df.loc[19] =  [1980, data[data.Element == "Food"].Y1980.sum()]
df.loc[20] =  [1981, data[data.Element == "Food"].Y1981.sum()]
df.loc[21] =  [1982, data[data.Element == "Food"].Y1982.sum()]
df.loc[22] =  [1983, data[data.Element == "Food"].Y1983.sum()]
df.loc[23] =  [1984, data[data.Element == "Food"].Y1984.sum()]
df.loc[24] =  [1985, data[data.Element == "Food"].Y1985.sum()]
df.loc[25] =  [1986, data[data.Element == "Food"].Y1986.sum()]
df.loc[26] =  [1987, data[data.Element == "Food"].Y1987.sum()]
df.loc[27] =  [1988, data[data.Element == "Food"].Y1988.sum()]
df.loc[28] =  [1989, data[data.Element == "Food"].Y1989.sum()]
df.loc[29] =  [1990, data[data.Element == "Food"].Y1990.sum()]
df.loc[30] =  [1991, data[data.Element == "Food"].Y1991.sum()]
df.loc[31] =  [1992, data[data.Element == "Food"].Y1992.sum()]
df.loc[32] =  [1993, data[data.Element == "Food"].Y1993.sum()]
df.loc[33] =  [1994, data[data.Element == "Food"].Y1994.sum()]
df.loc[34] =  [1995, data[data.Element == "Food"].Y1995.sum()]
df.loc[35] =  [1996, data[data.Element == "Food"].Y1996.sum()]
df.loc[36] =  [1997, data[data.Element == "Food"].Y1997.sum()]
df.loc[37] =  [1998, data[data.Element == "Food"].Y1998.sum()]
df.loc[38] =  [1999, data[data.Element == "Food"].Y1999.sum()]
df.loc[39] =  [2000, data[data.Element == "Food"].Y2000.sum()]
df.loc[40] =  [2001, data[data.Element == "Food"].Y2001.sum()]
df.loc[41] =  [2002, data[data.Element == "Food"].Y2002.sum()]
df.loc[42] =  [2003, data[data.Element == "Food"].Y2003.sum()]
df.loc[43] =  [2004, data[data.Element == "Food"].Y2004.sum()]
df.loc[44] =  [2005, data[data.Element == "Food"].Y2005.sum()]
df.loc[45] =  [2006, data[data.Element == "Food"].Y2006.sum()]
df.loc[46] =  [2007, data[data.Element == "Food"].Y2007.sum()]
df.loc[47] =  [2008, data[data.Element == "Food"].Y2008.sum()]
df.loc[48] =  [2009, data[data.Element == "Food"].Y2009.sum()]
df.loc[49] =  [2010, data[data.Element == "Food"].Y2010.sum()]
df.loc[50] =  [2011, data[data.Element == "Food"].Y2011.sum()]
df.loc[51] =  [2012, data[data.Element == "Food"].Y2012.sum()]
df.loc[52] =  [2013, data[data.Element == "Food"].Y2013.sum()]
'''

# %%
# get the sum for food+feed amount of each year for Ukraine
df.loc[0] =  ["1992", data.Y1992.sum()]
df.loc[1] =  ["1993", data.Y1993.sum()]
df.loc[2] =  ["1994", data.Y1994.sum()]
df.loc[3] =  ["1995", data.Y1995.sum()]
df.loc[4] =  ["1996", data.Y1996.sum()]
df.loc[5] =  ["1997", data.Y1997.sum()]
df.loc[6] =  ["1998", data.Y1998.sum()]
df.loc[7] =  ["1999", data.Y1999.sum()]
df.loc[8] =  ["2000", data.Y2000.sum()]
df.loc[9] =  ["2001", data.Y2001.sum()]
df.loc[11] =  ["2002", data.Y2002.sum()]
df.loc[12] =  ["2003", data.Y2003.sum()]
df.loc[13] =  ["2004", data.Y2004.sum()]
df.loc[14] =  ["2005", data.Y2005.sum()]
df.loc[15] =  ["2006", data.Y2006.sum()]
df.loc[16] =  ["2007", data.Y2007.sum()]
df.loc[17] =  ["2008", data.Y2008.sum()]
df.loc[18] =  ["2009", data.Y2009.sum()]
df.loc[19] =  ["2010", data.Y2010.sum()]
df.loc[20] =  ["2011", data.Y2011.sum()]
df.loc[21] =  ["2012", data.Y2012.sum()]
df.loc[22] =  ["2013", data.Y2013.sum()]

# %%
df
# Out:
#     Year       Qty
# 0   1992  157361.0
# 1   1993  156184.0
# 2   1994  144264.0
# 3   1995  136978.0
# 4   1996  129619.0
# 5   1997  124210.0
# 6   1998  119589.0
# 7   1999  112971.0
# 8   2000  118158.0
# 9   2001  118868.0
# 11  2002  131753.0
# 12  2003  120237.0
# 13  2004  145999.0
# 14  2005  135752.0
# 15  2006  144689.0
# 16  2007  136809.0
# 17  2008  152149.0
# 18  2009  126773.0
# 19  2010  142927.0
# 20  2011  167793.0
# 21  2012  143969.0
# 22  2013  153750.0

# %%
# output to csv
df.to_csv('final_vis1_barchart.csv')
